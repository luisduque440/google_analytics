# %%
import datetime as dt
import matplotlib as mp
import numpy as np
from data_wrangling import *
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 150)
# documentation: https://support.google.com/analytics/answer/3437719?hl=en

# %%
trainCSV = pd.read_csv('train_v2_flat.csv', sep=',', encoding='utf-8', low_memory=False).drop(columns=['trafficSource_campaignCode'])
trainCSV.head()
# Out:
#   channelGrouping      date        fullVisitorId     visitId  visitNumber  \
# 0  Organic Search  20171016  3162355547410993243  1508198450            1
# 1        Referral  20171016  8934116514970143966  1508176307            6
# 2          Direct  20171016  7992466427990357681  1508201613            1
# 3  Organic Search  20171016  9075655783635761930  1508169851            1
# 4  Organic Search  20171016  6960673291025684308  1508190552            1
#
#    visitStartTime device_browser device_deviceCategory  device_isMobile  \
# 0      1508198450        Firefox               desktop            False
# 1      1508176307         Chrome               desktop            False
# 2      1508201613         Chrome                mobile             True
# 3      1508169851         Chrome               desktop            False
# 4      1508190552         Chrome               desktop            False
#
#   device_operatingSystem                geoNetwork_city geoNetwork_continent  \
# ...

# %%
trainCSVf = fill_empty_values(trainCSV)
trainCSVf.head()
# Out:
#   channelGrouping                date        fullVisitorId  visitNumber  \
# 0  Organic Search 2017-10-17 00:00:50  3162355547410993243          1.0
# 1        Referral 2017-10-16 17:51:47  8934116514970143966          6.0
# 2          Direct 2017-10-17 00:53:33  7992466427990357681          1.0
# 3  Organic Search 2017-10-16 16:04:11  9075655783635761930          1.0
# 4  Organic Search 2017-10-16 21:49:12  6960673291025684308          1.0
#
#   device_browser device_deviceCategory device_isMobile device_operatingSystem  \
# 0        Firefox               desktop           False                Windows
# 1         Chrome               desktop           False              Chrome OS
# 2         Chrome                mobile            True                Android
# 3         Chrome               desktop           False                Windows
# 4         Chrome               desktop           False                Windows
#
# ...

# %%
df = trainCSVf[['fullVisitorId', 'date', 'geoNetwork_country', 'totals_totalTransactionRevenue']]
df['visit_counts']= [1.0]*len(df)
df.head()
# Out:
# /Users/lduque/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#          fullVisitorId                date geoNetwork_country  \
# 0  3162355547410993243 2017-10-17 00:00:50            Germany
# 1  8934116514970143966 2017-10-16 17:51:47      United States
# 2  7992466427990357681 2017-10-17 00:53:33      United States
# 3  9075655783635761930 2017-10-16 16:04:11             Turkey
# 4  6960673291025684308 2017-10-16 21:49:12             Mexico
#
#    totals_totalTransactionRevenue  visit_counts
# 0                             0.0           1.0
# 1                             0.0           1.0
# 2                             0.0           1.0
# 3                             0.0           1.0
# ...

# %%
get_basic_info(df)
# Out:
#                                          dtype  empty_values  \
# column_name
# fullVisitorId                           object             0
# date                            datetime64[ns]             0
# geoNetwork_country                      object             0
# totals_totalTransactionRevenue         float64             0
# visit_counts                           float64             0
#
#                                                mode  \
# column_name
# fullVisitorId                   1957458976293878100
# date                            2017-12-13 00:29:41
# geoNetwork_country                    United States
# totals_totalTransactionRevenue                    0
# visit_counts                                      1
#
#                                                                             types  \
# column_name
# fullVisitorId                                             {<type 'str'>: 1708337}
# ...
