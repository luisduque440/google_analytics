# %%
import datetime as dt
import matplotlib
import numpy as np
from analytics import *
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier
pd.set_option('display.max_columns', 150)
pd.set_option('display.max_rows', 150)

# %%
# %%time
train= pd.read_csv("train_features.csv", low_memory=False, index_col= 'fullVisitorId')
validation= pd.read_csv("validation_features.csv", low_memory=False, index_col= 'fullVisitorId')
test= pd.read_csv("test_features.csv", low_memory=False, index_col= 'fullVisitorId')
# Out:
# CPU times: user 42.6 s, sys: 4.05 s, total: 46.6 s
# Wall time: 52.3 s

# %%
features = list(train.columns)
features.remove('target')

columns_with_6_months = [c for c in features if "6_months" in c]
columns_without_months = [c for c in features if "months" not in c]

few_features = columns_without_months
more_features = columns_without_months + columns_with_6_months 
all_features = features

# %%
relevant_columns = all_features

train = train[relevant_columns + ['target']]
validation = validation[relevant_columns + ['target']]
test = test[relevant_columns] 


X_train = train.drop(columns=['target'])
y_train = train.target

X_validation = validation.drop(columns=['target'])
y_validation = validation.target

# %%
# %%time
parameters = {
    'max_depth':[5, 20],    
    'n_estimators': [50, 100], 
    'min_child_weight' : [10, 100], 
}
regr = XGBClassifier()
grid = GridSearchCV(regr, parameters, cv=2, scoring='neg_mean_squared_error', return_train_score=True)
grid.fit(X_train, y_train)
model = grid.best_estimator_
# Out:
# CPU times: user 3h 21min 10s, sys: 27.8 s, total: 3h 21min 37s
# Wall time: 3h 24min 54s

# %%
mean_test_scores = (-1)*grid.cv_results_['mean_test_score']
mean_train_scores = (-1)*grid.cv_results_['mean_train_score']
A =pd.DataFrame({'mean_test_scores':mean_test_scores, 'mean_train_scores':mean_train_scores})
A.plot()

# %%
print "croos validation score", grid.best_score_
print "best parameters:"
print grid.best_params_
# Out:
# croos validation score -0.10311962540846611
# best parameters:
# {'n_estimators': 50, 'max_depth': 5, 'min_child_weight': 10}

# %%
print "feature importance"
feature_importance = pd.DataFrame({'feature': X_train.columns, 'importance':model.feature_importances_}).set_index('feature').sort_values(by=['importance'], ascending=False)
feature_importance[feature_importance.importance>0].plot.bar(figsize=(15,5))
# Out:
# feature importance

# %%
get_validation_report(model, X_train, y_train, X_validation, y_validation)
# Out:
#    train_benchamrk  train_improvement  train_mse  validation_benchmark  \
# 0          0.10312                0.0    0.10312              0.110465
#
#    validation_improvement  validation_mse
# 0                     0.0        0.110465

# %%
print "Features not used by the model: "
print list(feature_importance[feature_importance.importance==0].index.values)
# Out:
# Features not used by the model:
# ['trafficSource_adwordsClickInfo.page_2_months_ago', 'paying_visits_3_months_ago', 'totals_transactions_2_months_ago', 'trafficSource_adwordsClickInfo.page_4_months_ago', 'totals_totalTransactionRevenue_2_months_ago', 'totals_hits_4_months_ago', 'totals_sessionQualityDim_2_months_ago', 'visits_4_months_ago', 'visits_2_months_ago', 'totals_transactions_4_months_ago', 'paying_visits_2_months_ago', 'totals_pageviews_4_months_ago', 'totals_sessionQualityDim_4_months_ago', 'totals_newVisits_2_months_ago', 'totals_transactionRevenue_3_months_ago', 'totals_sessionQualityDim_3_months_ago', 'totals_transactions_3_months_ago', 'totals_pageviews_3_months_ago', 'device_isMobile_4_months_ago', 'totals_newVisits_4_months_ago', 'totals_totalTransactionRevenue_4_months_ago', 'trafficSource_adwordsClickInfo.page_3_months_ago', 'totals_hits_3_months_ago', 'totals_transactionRevenue_4_months_ago', 'visits_3_months_ago', 'totals_bounces_3_months_ago', 'device_isMobile_3_months_ago', 'totals_newVisits_3_months_ago', 'totals_transactions_last_4_months', 'totals_bounces_2_months_ago', 'device_isMobile_last_3_months', 'trafficSource_adwordsClickInfo.page_last_1_months', 'totals_transactions_last_1_months', 'totals_sessionQualityDim_last_1_months', 'totals_bounces_last_1_months', 'device_isMobile_last_1_months', 'trafficSource_source', 'trafficSource_campaign', 'trafficSource_adwordsClickInfo.slot', 'trafficSource_adwordsClickInfo.isVideoAd', 'trafficSource_adwordsClickInfo.gclId', 'trafficSource_adwordsClickInfo.adNetworkType', 'trafficSource_adContent', 'geoNetwork_subContinent', 'geoNetwork_continent', 'device_deviceCategory', 'paying_visits_last_1_months', 'totals_newVisits_last_3_months', 'device_isMobile_2_months_ago', 'totals_sessionQualityDim_last_3_months', 'paying_visits_last_6_months', 'visits_last_6_months', 'trafficSource_adwordsClickInfo.page_last_6_months', 'totals_transactions_last_6_months', 'totals_sessionQualityDim_last_6_months', 'device_isMobile_last_6_months', 'paying_visits_last_4_months', 'visits_last_4_months', 'trafficSource_adwordsClickInfo.page_last_4_months', 'device_browser', 'totals_sessionQualityDim_last_4_months', 'totals_bounces_last_4_months', 'device_isMobile_last_4_months', 'trafficSource_adwordsClickInfo.page_last_3_months', 'totals_transactions_last_3_months', 'paying_visits_4_months_ago']

# %%
## retrain model for submision
file_name = "results_xgboost_all_features.csv"

X = pd.concat([X_train, X_validation], ignore_index=True)
y = pd.concat([y_train, y_validation], ignore_index=True)
regr = XGBClassifier(max_depth = , n_estimators=, min_child_weight=)
regr.fit(X, y)
y_predicted = regr.predict(test)
test['PredictedLogRevenue']= list(y_predicted)
results = test[['PredictedLogRevenue']].reset_index()
results.to_csv(file_name, float_format='%.12f', index=False)
# Out:
#   File "<ipython-input-11-6a34d8cb1551>", line 6
#     regr = XGBClassifier(max_depth = , n_estimators=, min_child_weight=)
#                                      ^
# SyntaxError: invalid syntax
